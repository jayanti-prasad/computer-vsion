# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 
from PIL import Image
import sys


if __name__ == "__main__":
    
    image1 = "data/Monalisa.jpg"
    image2 = "data/Hispine.jpg"
    image3 = "data/garden.png"
    image4 = 'data/W.png'
    
    image = cv2.imread(image1)
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    image_color = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
 
    image_gray  = cv2.resize (image_gray, (400, 600))
    image_color  = cv2.resize (image_color, (400, 600))

    (thresh, image_bw) = cv2.threshold(image_gray, 127, 255, cv2.THRESH_BINARY)
    
    fig, axs = plt.subplots (2,3,figsize=(24,15))
    axs[0,1].imshow (image_gray,cmap='gray')
    axs[0,0].imshow (image_color)
    axs[0,2].imshow (image_bw,cmap='gray')
    
    axs[1,0].hist (image_color[:,:,0].ravel(), histtype='step', stacked=True, fill=False,color='red')
    axs[1,0].hist (image_color[:,:,1].ravel(), histtype='step', stacked=True, fill=False,color='green')
    axs[1,0].hist (image_color[:,:,2].ravel(), histtype='step', stacked=True, fill=False,color='blue')
    
    axs[1,1].hist (image_gray.ravel(), stacked=True, fill=False)
    axs[1,2].hist (image_bw.ravel(), stacked=True, fill=False)    
        
    
    
    print ("black and white image min:", np.min (image_bw.ravel()))
    print ("black and white image max:", np.max (image_bw.ravel()))
    
    
    
    plt.show()
# Out:
# black and white image min: 0
# black and white image max: 255
